# %% [markdown]
# # MMS dayside magnetopause
#
# This notebook performs analysis on MMS2 data at the dayside magnetopause:
#
# 1. **Walen Test** — compares plasma flow velocity to Alfven velocity
# 2. **Mirror Mode** — computes the mirror instability criterion
# 3. **Visualization** — multi-panel overview with spectrograms, B-field, velocity, density, temperature
# 4. **Catalog creation** — save identified events for later use
#
# Time period: November 18, 2015 02:14:30 – 03:34:00 UT

# %% [markdown]
# ## 1. Virtual products via `%%vp` magic

# %%
# %%vp --path "mms_vprods/mms2/vwalen"
# from datetime import datetime
# import speasy as spz
# import numpy as np
# import scipy
# import scipy.constants as cst
#
# def mms2_walen(start: datetime, stop: datetime) -> Vector["x", "y", "z"]:
#     v = spz.get_data(
#         spz.inventories.data_tree.cda.MMS.MMS2.DIS.MMS2_FPI_FAST_L2_DIS_MOMS.mms2_dis_bulkv_gse_fast,
#         start, stop)
#     b = spz.get_data(
#         spz.inventories.tree.cda.MMS.MMS2.FGM.MMS2_FGM_SRVY_L2.mms2_fgm_b_gsm_srvy_l2,
#         start, stop)
#     N = spz.get_data(
#         spz.inventories.data_tree.cda.MMS.MMS2.DIS.MMS2_FPI_FAST_L2_DIS_MOMS.mms2_dis_numberdensity_fast,
#         start, stop)
#
#     vx, vy, vz = v["Vx_GSE"].values[:, 0], v["Vy_GSE"].values[:, 0], v["Vz_GSE"].values[:, 0]
#     t = v["Vx_GSE"].time.astype(np.timedelta64) / np.timedelta64(1, "s")
#     tb = b["Bt"].time.astype(np.timedelta64) / np.timedelta64(1, "s")
#
#     Nfunc = scipy.interpolate.interp1d(t, N.values[:, 0], bounds_error=False, fill_value="extrapolate")
#     NonB = Nfunc(tb)
#
#     Va_factor = 1e-9 / np.sqrt(cst.mu_0 * cst.m_p * NonB * 1e6)
#     Vax = b["Bx GSM"].values[:, 0] * Va_factor
#     Vay = b["By GSM"].values[:, 0] * Va_factor
#     Vaz = b["Bz GSM"].values[:, 0] * Va_factor
#
#     imid = Vax.size // 2
#     vw = np.zeros((Vax.size, 3))
#     vw[:imid, 0] = (vx[0] * 1e3 + Vax[:imid] - Vax[0]) / 1e3
#     vw[imid:, 0] = (vx[-1] * 1e3 + Vax[imid:] - Vax[-1]) / 1e3
#     vw[:imid, 1] = (vy[0] * 1e3 + Vay[:imid] - Vay[0]) / 1e3
#     vw[imid:, 1] = (vy[-1] * 1e3 + Vay[imid:] - Vay[-1]) / 1e3
#     vw[:imid, 2] = (vz[0] * 1e3 + Vaz[:imid] - Vaz[0]) / 1e3
#     vw[imid:, 2] = (vz[-1] * 1e3 + Vaz[imid:] - Vaz[-1]) / 1e3
#
#     return tb, vw

# %%
# %%vp --path "mms_vprods/mms2/mirror_cm"
# from datetime import datetime
# import speasy as spz
# import numpy as np
# import scipy
# import scipy.constants as cst
#
# def mms2_mirror_cm(start: datetime, stop: datetime) -> Scalar["C_M_b"]:
#     b = spz.get_data(
#         spz.inventories.tree.cda.MMS.MMS2.FGM.MMS2_FGM_SRVY_L2.mms2_fgm_b_gsm_srvy_l2,
#         start, stop)
#     Tperp = spz.get_data(
#         spz.inventories.data_tree.cda.MMS.MMS2.DIS.MMS2_FPI_FAST_L2_DIS_MOMS.mms2_dis_tempperp_fast,
#         start, stop)
#     Tpara = spz.get_data(
#         spz.inventories.data_tree.cda.MMS.MMS2.DIS.MMS2_FPI_FAST_L2_DIS_MOMS.mms2_dis_temppara_fast,
#         start, stop)
#     N = spz.get_data(
#         spz.inventories.data_tree.cda.MMS.MMS2.DIS.MMS2_FPI_FAST_L2_DIS_MOMS.mms2_dis_numberdensity_fast,
#         start, stop)
#
#     anisotropy = Tperp["eT_perp"].values / Tpara["eT_para"].values
#     bt = b["Bt"].values
#     Pperp = N["N"].values * Tperp["eT_perp"].values
#     tb = b["Bt"].time.astype(np.timedelta64) / np.timedelta64(1, "s")
#     tp = N.time.astype(np.timedelta64) / np.timedelta64(1, "s")
#
#     pfunc = scipy.interpolate.interp1d(tp, Pperp[:, 0], bounds_error=False)
#     Afunc = scipy.interpolate.interp1d(tp, anisotropy[:, 0], bounds_error=False)
#     betaperp = pfunc(tb) * 1e6 * cst.e * 2 * cst.mu_0 / (bt[:, 0] * 1e-9) ** 2
#     cm = scipy.ndimage.gaussian_filter1d(betaperp * (Afunc(tb) - 1), 6)
#
#     return tb, cm

# %% [markdown]
# ## 2. Multi-panel visualization with the fluent API

# %%
from SciQLop.user_api.plot import fluent

builder = (fluent.new_panel()
    # Energy spectrogram
    .plot("speasy/cda/MMS/MMS2/DIS/MMS2_FPI_FAST_L2_DIS_MOMS/mms2_dis_energyspectr_omni_fast")

    # Velocity: survey + burst overlay
    .subplot()
    .plot("speasy/cda/MMS/MMS2/DIS/MMS2_FPI_FAST_L2_DIS_MOMS/mms2_dis_bulkv_gse_fast")
    .plot("speasy/cda/MMS/MMS2/DIS/MMS2_FPI_BRST_L2_DIS_MOMS/mms2_dis_bulkv_gse_brst")
    .y_range(-450, 450)

    # Mirror mode criterion
    .subplot()
    .plot("mms_vprods/mms2/mirror_cm")
    .y_range(-4, 6)

    # Walen test
    .subplot()
    .plot("mms_vprods/mms2/vwalen")
    .y_range(-300, 300)

    # Magnetic field
    .subplot()
    .plot("speasy/cda/MMS/MMS2/FGM/MMS2_FGM_SRVY_L2/mms2_fgm_b_gsm_srvy_l2")
    .y_range(-75, 75)

    # Temperature: parallel + perpendicular overlay
    .subplot()
    .plot("speasy/cda/MMS/MMS2/DIS/MMS2_FPI_FAST_L2_DIS_MOMS/mms2_dis_temppara_fast")
    .plot("speasy/cda/MMS/MMS2/DIS/MMS2_FPI_FAST_L2_DIS_MOMS/mms2_dis_tempperp_fast")
    .log_y()
    .y_range(180, 1500)

    # Density: survey + burst overlay
    .subplot()
    .plot("speasy/cda/MMS/MMS2/DIS/MMS2_FPI_FAST_L2_DIS_MOMS/mms2_dis_numberdensity_fast")
    .plot("speasy/cda/MMS/MMS2/DIS/MMS2_FPI_BRST_L2_DIS_MOMS/mms2_dis_numberdensity_brst")
    .log_y()
    .y_range(0.001, 50)

    .time_range("2015-11-18T02:14:30", "2015-11-18T03:34:00"))

# %% [markdown]
# ## 3. Save identified events to a catalog
#
# After visual inspection, record the magnetopause crossings as a catalog for later retrieval.

# %%
from datetime import timezone
from SciQLop.user_api.catalogs import catalogs

crossings = [
    (datetime(2015, 11, 18, 2, 20, 0, tzinfo=timezone.utc),
     datetime(2015, 11, 18, 2, 30, 0, tzinfo=timezone.utc),
     {"type": "magnetopause_crossing", "spacecraft": "MMS2"}),

    (datetime(2015, 11, 18, 3, 5, 0, tzinfo=timezone.utc),
     datetime(2015, 11, 18, 3, 15, 0, tzinfo=timezone.utc),
     {"type": "magnetopause_crossing", "spacecraft": "MMS2"}),
]

catalogs.save("My Catalogs//mms2_mp_crossings_20151118", crossings)

# %% [markdown]
# ## 4. Export the plot

# %%
# builder.panel.save("/tmp/mms2_magnetopause_overview.png")
